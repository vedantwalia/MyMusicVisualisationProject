# %%
import pandas as pd
import numpy as np
from lxml import objectify
import xml.etree.ElementTree as ET
import requests
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import style
import os
import re
import pycats
import warnings
warnings.filterwarnings("ignore")
# Out:
# /Users/vedantwalia/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
tree = ET.parse('Library.xml')
root = tree.getroot()
root
# Out:
# <Element 'plist' at 0x10a7cb310>

# %%
main_dict=root.findall('dict')

for index, item in enumerate(list(main_dict[0])):  
    print('index #{} = <{}>'.format(index, item.tag))
    if item.tag=="dict":
        print('The tracks dict has been found!')
        tracks_dict=item
        break
# Out:
# index #0 = <key>
# index #1 = <integer>
# index #2 = <key>
# index #3 = <integer>
# index #4 = <key>
# index #5 = <date>
# index #6 = <key>
# index #7 = <string>
# index #8 = <key>
# index #9 = <integer>
# index #10 = <key>
# index #11 = <true>
# index #12 = <key>
# index #13 = <string>
# index #14 = <key>
# index #15 = <string>
# index #16 = <key>
# index #17 = <dict>
# The tracks dict has been found!

# %%
tracklist = list(tracks_dict.findall('dict'))
len(tracklist)
# Out:
# 6487

# %%
kinds = set([])
for i in range(len(tracklist)):
    for j in range(len(tracklist[i])):
        if (tracklist[i][j].tag == 'key' and tracklist[i][j].text== 'Kind'):
            kinds.add(tracklist[i][j+1].text)

kinds = pd.Series(list(kinds))
kinds
# Out:
# 0             MPEG-4 video file
# 1               MPEG audio file
# 2      Purchased AAC audio file
# 3                AAC audio file
# 4    Apple Music AAC audio file
# dtype: object

# %%
valid_datatypes = pd.Series([
    'AAC audio file',
    'MPEG audio file',
    'MPEG audio file',
    'Apple Music AAC audio file'
])

# %%
# This code will retrieve all the 'keys' (attributes) of the first track of the corresponding Kind
def cols(kind):
    cols = []
    kind_found = False
    for i in range(len(tracklist)):
        for j in range(len(tracklist[i])):
            if tracklist[i][j].tag == "key":
                cols.append(tracklist[i][j].text)
            if (j < len(tracklist[i]) - 1 and tracklist[i][j].text == "Kind" and tracklist[i][j + 1].text == kind):
                kind_found = True
                break  # Once the kind is found, break the inner loop
        if kind_found:
            return set(cols)  # Return the set of columns if kind is found

# Sample usage
cols('AAC audio file')
# Out:
# {'Album',
#  'Album Artist',
#  'Album Loved',
#  'Apple Music',
#  'Artist',
#  'Artwork Count',
#  'Bit Rate',
#  'Clean',
#  'Compilation',
#  'Composer',
#  'Date Added',
#  'Date Modified',
#  'Disc Count',
#  'Disc Number',
#  'Explicit',
#  'Favorited',
#  'Genre',
#  'Kind',
#  'Loved',
#  'Name',
#  'Normalization',
#  'Part Of Gapless Album',
#  'Persistent ID',
#  'Play Count',
#  'Play Date',
#  'Play Date UTC',
#  'Playlist Only',
#  'Purchased',
#  'Release Date',
#  'Sample Rate',
#  'Size',
#  'Skip Count',
#  'Skip Date',
#  'Sort Album',
#  'Sort Album Artist',
#  'Sort Artist',
#  'Sort Composer',
#  'Sort Name',
#  'Total Time',
#  'Track Count',
#  'Track ID',
#  'Track Number',
#  'Track Type',
#  'Year'}

# %%
results = map(cols, valid_datatypes)
results_list = [list(item) for item in results]
results_list
# Out:
# [['Artist',
#   'Disc Number',
#   'Track Count',
#   'Purchased',
#   'Date Added',
#   'Artwork Count',
#   'Composer',
#   'Size',
#   'Bit Rate',
#   'Explicit',
#   'Genre',
#   'Year',
#   'Skip Count',
#   'Part Of Gapless Album',
#   'Play Date UTC',
#   'Track ID',
#   'Sample Rate',
#   'Album',
#   'Track Number',
#   'Apple Music',
#   'Skip Date',
#   'Favorited',
#   'Persistent ID',
#   'Track Type',
#   'Album Loved',
#   'Sort Album Artist',
#   'Sort Composer',
#   'Compilation',
#   'Loved',
#   'Kind',
#   'Total Time',
#   'Name',
#   'Play Count',
#   'Play Date',
#   'Normalization',
#   'Disc Count',
#   'Playlist Only',
#   'Clean',
#   'Album Artist',
#   'Release Date',
#   'Sort Name',
#   'Date Modified',
#   'Sort Album',
#   'Sort Artist'],
#  ['Artist',
#   'Disc Number',
#   'Track Count',
#   'Purchased',
#   'Date Added',
#   'Artwork Count',
#   'Matched',
#   'Composer',
#   'Size',
#   'Bit Rate',
#   'Explicit',
#   'Genre',
#   'Year',
#   'Skip Count',
#   'Part Of Gapless Album',
#   'Play Date UTC',
#   'Track ID',
#   'Sample Rate',
#   'Album',
#   'Track Number',
#   'Apple Music',
#   'Skip Date',
#   'Favorited',
#   'Grouping',
#   'Disliked',
#   'Persistent ID',
#   'Track Type',
#   'Album Loved',
#   'Sort Album Artist',
#   'Sort Composer',
#   'Compilation',
#   'Loved',
#   'Kind',
#   'Total Time',
#   'Name',
#   'Play Count',
#   'Play Date',
#   'Normalization',
#   'Disc Count',
#   'Playlist Only',
#   'Clean',
#   'Album Artist',
#   'Release Date',
#   'Sort Name',
#   'Date Modified',
#   'Sort Album',
#   'Sort Artist'],
#  ['Artist',
#   'Disc Number',
#   'Track Count',
#   'Purchased',
#   'Date Added',
#   'Artwork Count',
#   'Matched',
#   'Composer',
#   'Size',
#   'Bit Rate',
#   'Explicit',
#   'Genre',
#   'Year',
#   'Skip Count',
#   'Part Of Gapless Album',
#   'Play Date UTC',
#   'Track ID',
#   'Sample Rate',
#   'Album',
#   'Track Number',
#   'Apple Music',
#   'Skip Date',
#   'Favorited',
#   'Grouping',
#   'Disliked',
#   'Persistent ID',
#   'Track Type',
#   'Album Loved',
#   'Sort Album Artist',
#   'Sort Composer',
#   'Compilation',
#   'Loved',
#   'Kind',
#   'Total Time',
#   'Name',
#   'Play Count',
#   'Play Date',
#   'Normalization',
#   'Disc Count',
#   'Playlist Only',
#   'Clean',
#   'Album Artist',
#   'Release Date',
#   'Sort Name',
#   'Date Modified',
#   'Sort Album',
#   'Sort Artist'],
#  ['Artist',
#   'Album',
#   'Kind',
#   'Album Artist',
#   'Composer',
#   'Name',
#   'Genre',
#   'Track ID']]

# %%
flat_list=[]

for item in results_list:
  for sub_item in item:
    flat_list.append(sub_item)

unique_cols = set(flat_list) # set funcation gives unique items list

print(unique_cols)
# Out:
# {'Artist', 'Disc Number', 'Track Count', 'Purchased', 'Date Added', 'Artwork Count', 'Matched', 'Composer', 'Size', 'Bit Rate', 'Explicit', 'Genre', 'Year', 'Skip Count', 'Play Date UTC', 'Part Of Gapless Album', 'Track ID', 'Sample Rate', 'Album', 'Track Number', 'Apple Music', 'Skip Date', 'Favorited', 'Grouping', 'Disliked', 'Persistent ID', 'Track Type', 'Album Loved', 'Sort Album Artist', 'Sort Composer', 'Compilation', 'Loved', 'Kind', 'Total Time', 'Name', 'Play Count', 'Play Date', 'Normalization', 'Disc Count', 'Playlist Only', 'Clean', 'Album Artist', 'Release Date', 'Sort Name', 'Date Modified', 'Sort Album', 'Sort Artist'}

# %%
len(unique_cols) # superset of all common unique entries between all the filetypes
# Out:
# 47

# %%
unique_cols_list = list(unique_cols)

df_tracks=pd.DataFrame(columns=unique_cols_list)

dict1={}

for song_i in range(len(tracklist)):
  for attribute_i in range(len(tracklist[song_i])):
    if tracklist[song_i][attribute_i].tag=="key":
      dict1[tracklist[song_i][attribute_i].text]=tracklist[song_i][attribute_i+1].text
  list_values=[i for i in dict1.values()]
  list_keys=[j for j in dict1.keys()]
  if dict1['Kind'] in valid_datatypes.unique():
    df_temp=pd.DataFrame([list_values],columns=list_keys)
    df_tracks=pd.concat([df_tracks,df_temp],axis=0,ignore_index=True,sort=True)

# %%
#df_tracks = df_tracks[df_tracks['Play Count'].notna()]

# %%
#df_tracks = df_tracks.dropna(axis=1)
df_tracks
# Out:
#                                           Album           Album Artist  \
# 0     MTV Unplugged In New York (Live Acoustic)                Nirvana
# 1                                       Rumours          Fleetwood Mac
# 2                It Will Never Be the Same - EP            Michigander
# 3                                    SUCKAPUNCH          You Me At Six
# 4                       Can't Tame Her - Single           Zara Larsson
# ...                                         ...                    ...
# 6462                   WE STILL DON'T TRUST YOU  Future & Metro Boomin
# 6463            Superunknown (20th Anniversary)            Soundgarden
# 6464   Non-Stop Erotic Cabaret (Deluxe Edition)              Soft Cell
# 6465                    musicforthemorningafter              Pete Yorn
# 6466                            Friday - Single               Flo Rida
#
#      Album Loved Apple Music                             Artist Artwork Count  \
# 0            NaN        None                            Nirvana             1
# 1            NaN        None                      Fleetwood Mac             1
# 2            NaN        None                        Michigander             1
# 3            NaN        None                      You Me At Six             1
# 4            NaN        None                       Zara Larsson             1
# ...          ...         ...                                ...           ...
# 6462         NaN        None  Future, Metro Boomin & The Weeknd             1
# 6463         NaN        None                        Soundgarden             1
# 6464         NaN        None                          Soft Cell             1
# 6465         NaN        None                          Pete Yorn             1
# 6466        None        None                           Flo Rida             1
#
#       BPM Bit Rate Clean                                           Comments  \
# 0     NaN      256   NaN                                                NaN
# 1     NaN      256   NaN                                                NaN
# 2     NaN      256   NaN                                                NaN
# 3     NaN      256   NaN                                                NaN
# 4     NaN      256   NaN                                                NaN
# ...   ...      ...   ...                                                ...
# 6462   90      256   NaN   00001511 00001567 0000CABB 0000B8E1 00036324 ...
# 6463   90      256   NaN   00001511 00001567 0000CABB 0000B8E1 00036324 ...
# 6464   90      256   NaN   00001511 00001567 0000CABB 0000B8E1 00036324 ...
# 6465   90      256   NaN   00001511 00001567 0000CABB 0000B8E1 00036324 ...
# 6466   90      256  None   00001511 00001567 0000CABB 0000B8E1 00036324 ...
#
#       ...                          Sort Composer  \
# 0     ...                                    NaN
# 1     ...                                    NaN
# 2     ...                                    NaN
# 3     ...                                    NaN
# 4     ...                                    NaN
# ...   ...                                    ...
# 6462  ...  Edge, Adam Clayton & Larry Mullen Jr.
# 6463  ...  Edge, Adam Clayton & Larry Mullen Jr.
# 6464  ...  Edge, Adam Clayton & Larry Mullen Jr.
# 6465  ...  Edge, Adam Clayton & Larry Mullen Jr.
# 6466  ...  Edge, Adam Clayton & Larry Mullen Jr.
#
#                            Sort Name Total Time Track Count Track ID  \
# 0       About a Girl (Live Acoustic)     218000          14     6857
# 1                    Go Your Own Way     223613          12     6859
# 2                         Cannonball     245945           6     6861
# 3                         SUCKAPUNCH     299880          10     6863
# 4                     Can't Tame Her     196940           1     6865
# ...                              ...        ...         ...      ...
# 6462        We Still Don't Trust You     252920          18    38963
# 6463                  Black Hole Sun     318587          15    38965
# 6464  Tainted Love (Remastered 2023)     154733          19    38967
# 6465                 Life On a Chain     226646          15    38969
# 6466                          Friday     157993           2    39269
#
#      Track Number Track Type Volume Adjustment  Work  Year
# 0               1     Remote               NaN   NaN  1994
# 1               5     Remote               NaN   NaN  1977
# 2               6     Remote               NaN   NaN  2023
# 3               5     Remote               NaN   NaN  2020
# 4               1     Remote               NaN   NaN  2023
# ...           ...        ...               ...   ...   ...
# 6462            1     Remote                48  1999  2024
# 6463            7     Remote                48  1999  1994
# 6464            2     Remote                48  1999  1981
# 6465            1     Remote                48  1999  2001
# 6466            1     Remote                48  1999  2024
#
# [6467 rows x 54 columns]

# %%
df_tracks[['Play Count']] = df_tracks[['Play Count']].apply(pd.to_numeric)

# %%
top_songs=(df_tracks.sort_values(by='Play Count', ascending=False)[['Name', 'Artist', 'Play Count', 'Genre']])

top_songs
# Out:
#                                                    Name  \
# 4555                            Save Your Tears (Remix)
# 4857    Self Love (Spider-Man: Across the Spider-Verse)
# 4510                          Wish On An Eyelash, Pt. 2
# 4476                                     Eyes Wide Shut
# 4813  Electric Touch (Taylor's Ve rsion) (From The V...
# ...                                                 ...
# 126                                        The Stranger
# 127                                            Chemical
# 128                                       Too Far Gone?
# 129                     Gangsta's Paradise (feat. L.V.)
# 130                                       Break With Me
#
#                                        Artist  Play Count        Genre
# 4555               The Weeknd & Ariana Grande       112.0     R&B/Soul
# 4857                 Metro Boomin & Coi Leray        98.0  Hip-Hop/Rap
# 4510               Mallrat & The Chainsmokers        83.0  Alternative
# 4476  ILLENIUM, Avril Lavigne & Travis Barker        78.0        Dance
# 4813                             Taylor Swift        70.0          Pop
# ...                                       ...         ...          ...
# 126                            Ingrid Andress         NaN      Country
# 127                               Post Malone         NaN          Pop
# 128                                 Metallica         NaN        Metal
# 129                                    Coolio         NaN  Hip-Hop/Rap
# 130                                SHY Martin         NaN          Pop
#
# [6467 rows x 4 columns]

# %%
plt.clf()
ax=sns.barplot(x='Play Count',
            y='Name',
            hue='Artist',
            data=top_songs.head(10),
            dodge=False,
            palette=sns.color_palette("Set1"))
ax.figure.set_size_inches(7,5)
ax.legend(fontsize=8, loc='upper left', bbox_to_anchor=(1, 1))
ax.xaxis.grid(True)
ax.set_ylabel('Track', fontsize=4)
#plt.savefig('test.png', dpi=400)
plt.show()

# %%
ntracks_album=df_tracks.groupby('Album').size()
full_albums=(ntracks_album[ntracks_album>5]
             .reset_index()
             .rename(columns={0: "n_tracks"}))
full_albums
# Out:
#                                                  Album  n_tracks
# 0                                                   #3         9
# 1    (What's the Story) Morning Glory? [Deluxe Edit...         9
# 2                              1989 (Taylor's Version)        21
# 3                                                    =        14
# 4                                A Head Full Of Dreams         9
# ..                                                 ...       ...
# 146                                   misery lake - EP         6
# 147                                          no future        19
# 148                                         reputation         7
# 149                                            vertigo        13
# 150                                  ~How I'm Feeling~        29
#
# [151 rows x 2 columns]

# %%
plays_by_album=(df_tracks
                .groupby('Album')['Play Count']
                .sum()
                .reset_index()
                .sort_values(by='Play Count', ascending=False))

full_albums_ranked=plays_by_album[plays_by_album.Album.isin(full_albums.Album)]
full_albums_ranked.head(10)
# Out:
#                                                   Album  Play Count
# 1550                                           ILLENIUM       311.0
# 1923  METRO BOOMIN PRESENTS SPIDER-MAN: ACROSS THE S...       294.0
# 3806                                         reputation       277.0
# 1050                     Fallen Embers (Deluxe Version)       204.0
# 2788                       Speak Now (Taylor's Version)       188.0
# 505                                          Blurryface       155.0
# 2591                                            Savages       151.0
# 3788           mainstream sellout (life in pink deluxe)       132.0
# 2609                Scaled And Icy (Livestream Version)       130.0
# 1525            I met you when I was 18. (the playlist)       124.0

# %%
plt.clf()
ax=sns.barplot(x='Play Count',
               y='Album',
               hue='Play Count',
              data=full_albums_ranked.head(10),
              dodge='auto',
              palette='RdBu')
ax.tick_params(axis='y', labelsize=6)
ax.xaxis.grid(True)
plt.show()

# %%
delimiters=' & ',', ',' Feat. ',' feat. ','/'
regexPattern = '|'.join(map(re.escape, delimiters))
reg_split=re.compile(regexPattern)
artists_splitted=df_tracks.Artist.str.split(regexPattern)
artists_splitted
# Out:
# 0                                [Nirvana]
# 1                          [Fleetwood Mac]
# 2                            [Michigander]
# 3                          [You Me At Six]
# 4                           [Zara Larsson]
#                        ...
# 6462    [Future, Metro Boomin, The Weeknd]
# 6463                         [Soundgarden]
# 6464                           [Soft Cell]
# 6465                           [Pete Yorn]
# 6466                            [Flo Rida]
# Name: Artist, Length: 6467, dtype: object

# %%
songs=[]
for i, song in df_tracks.Name.items():
  ## Parse the artists of the song
  if df_tracks.Artist.values[i]=='Now, Now':
    artist_to_assign=[df_tracks.Artist.values[i]]
  else:
    artist_to_assign=artists_splitted.values[i]

  ## add elements to the list of songs
  songs.append({'Name': song,
                'Number': i,
                'Artists': artist_to_assign})

songs[:5]
# Out:
# [{'Name': 'About a Girl (Live Acoustic)', 'Number': 0, 'Artists': ['Nirvana']},
#  {'Name': 'Go Your Own Way', 'Number': 1, 'Artists': ['Fleetwood Mac']},
#  {'Name': 'Cannonball', 'Number': 2, 'Artists': ['Michigander']},
#  {'Name': 'SUCKAPUNCH', 'Number': 3, 'Artists': ['You Me At Six']},
#  {'Name': "Can't Tame Her", 'Number': 4, 'Artists': ['Zara Larsson']}]

# %%
# One regex for each pattern variation: round brackets, squared brackets, and no brackets
# Note how in the variations with brackets we have to look for the closing bracket, while in the "bare" variation we just extract everthying from "feat." to the end of the string
re_circ_brackets=re.compile(' \(feat\.* (.*)\)')
re_sq_brackets=re.compile(' \[feat. ([^\[]*)\]')
re_bare=re.compile(' feat. (.*)$')

# Creating bolean arrays based on which of the pattern variations is present in the song name (note that it could be none)
feat_curved_brackets=df_tracks.Name.str.contains('\(feat.').values
feat_squared_brackets=df_tracks.Name.str.contains('\[feat.').values
feat_bare=df_tracks.Name.str.contains(' feat.').values

# %%
df_tracks_clean = df_tracks.dropna(subset=['Play Count'])

df_tracks_clean['Play Count'].dtype
# Out:
# dtype('float64')

# %%
for i, song in df_tracks_clean.Name.items():
  if feat_curved_brackets[i]:
    artists_feat=re_circ_brackets.search(song)[1]
  elif feat_squared_brackets[i]:
    artists_feat=re_sq_brackets.search(song)[1]
  elif feat_bare[i]:
    artists_feat=re_bare.search(song)[1]

  if (feat_curved_brackets[i] or feat_squared_brackets[i] or feat_bare[i]):
    splitted_artists_feat=reg_split.split(artists_feat)
    songs[i]['Artists'].extend(splitted_artists_feat)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 7
#       5   artists_feat=re_sq_brackets.search(song)[1]
#       6 elif feat_bare[i]:
# ----> 7   artists_feat=re_bare.search(song)[1]
#       9 if (feat_curved_brackets[i] or feat_squared_brackets[i] or feat_bare[i]):
#      10   splitted_artists_feat=reg_split.split(artists_feat)
#
# TypeError: 'NoneType' object is not subscriptable
